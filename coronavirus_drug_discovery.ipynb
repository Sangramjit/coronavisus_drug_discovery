# %% [markdown]
# <a href="https://colab.research.google.com/github/Sangramjit/coronavisus_drug_discovery/blob/main/coronavirus_drug_discovery.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Computational Drug Discovery for Coronavirus ( SARS coronavirus 3C-like proteinas)**
# ###### The 3C-like protease (3CLpro) or Mpro, formally known as C30 Endopeptidase, is the main protease found in coronaviruses. It cleaves the
# coronavirus polyprotein at eleven conserved sites. It is a cysteine
# protease and a member of the PA clan of proteases. It has a
# cysteine-histidine catalytic dyad at its active site and cleaves a Gln–(Ser/Ala/Gly) peptide bond.
# The Enzyme Commission refers to this family as SARS coronavirus main proteinase. The 3CL protease corresponds to coronavirus nonstructural protein 5 (nsp5). The "3C" in the common name refers to the 3C protease (3Cpro) which is a homologous protease found in picornaviruses.
#
# ![387px-DOI.10.1126.science.abb4489.S2.png](data:image/png;base64,...)
#
#
# ---

# %% [markdown]
# ### **ChEMBL Database**
# The ChEMBL Database is a database that contains curated bioactivity data of more than 2 million compounds. It is compiled from more than 76,000 documents, 1.2 million assays and the data spans 13,000 targets and 1,800 cells and 33,000 indications.

# %%
pip install chembl_webresource_client

# %%
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %%
target=new_client.target 
target_query=target.search('coronavirus')
targets=pd.DataFrame.from_dict(target_query)
targets

# %% [markdown]
# #### **Select and retrive bioactivity data for SARS coronavirus 3C-like proteinase**
# ###### We will assign the fifth entry ( which corresponds to the target protine 3C lke proteinase) to the select_target variable

# %%
selected_target=targets.target_chembl_id[4]
selected_target

# %% [markdown]
# ##### Here we will retrive only bioactivity data for coronavirus 3C-like proteinese ( CHEMBL 3927) that are reported as IC50 value.

# %%
activity=new_client.activity
res=activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %% [markdown]
# #### **What is Bioactivity?**
# ##### In pharmacology, biological activity or pharmacological activity describes the beneficial or adverse effects of a drug on living matter. When a drug is a complex chemical mixture, this activity is exerted by the substance's active ingredient or pharmacophore but can be modified by the other constituents. Among the various properties of chemical compounds, pharmacological/biological activity plays a crucial role since it suggests uses of the compounds in the medical applications. However, chemical compounds may show some adverse and toxic effects which may prevent their use in medical practice.
# #### **What is IC50?**
# ##### The half maximal inhibitory concentration (IC50) is a measure of the potency of a substance in inhibiting a specific biological or biochemical function. IC50 is a quantitative measure that indicates how much of a particular inhibitory substance (e.g. drug) is needed to inhibit, in vitro, a given biological process or biological component by 50%. The biological component could be an enzyme, cell, cell receptor or microorganism. IC50 values are typically expressed as molar concentration.
#
# [More on IC50](https://https://www.collaborativedrug.com/why-using-pic50-instead-of-ic50-will-change-your-life/)
#
# ![330px-Example_IC50_curve_demonstrating_visually_how_IC50_is_derived.png](data:image/png;base64,...)
# #### **What is Potency?**
# ##### In the field of pharmacology, potency is a measure of drug activity expressed in terms of the amount required to produce an effect of given intensity. A highly potent drug evokes a given response at low concentrations, while a drug of lower potency evokes the same response only at higher concentrations.
# ![Potency_Figure16.png](data:image/png;base64,...)
#
# ###### ***Lower the number of potency better the drug become***

# %%
df= pd.DataFrame.from_dict(res)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-67fa84500317> in <module>()
# ----> 1 df= pd.DataFrame.from_dict(res)
#
# NameError: name 'res' is not defined

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-c42a15b2c7cf> in <module>()
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %% [markdown]
# #### Watch for unique values in the columns

# %%
df.standard_type.unique()
df.standard_value.unique()
# Out:
# array(['7200.0', '9400.0', '13500.0', '13110.0', '2000.0', '980.0',
#        '4820.0', '950.0', '11200.0', '23500.0', '12570.0', '17500.0',
#        '45000.0', '70000.0', '66000.0', '370.0', '12500.0', '19000.0',
#        '25000.0', '71000.0', '1100.0', '50000.0', '331131121482590.75',
#        '3000.0', '3311311214825.91', '300000.0', '3981071705534.97',
#        '250000.0', '4897788193684.46', '200000.0', '10000000000000.0',
#        '100000.0', '16595869074375.56', '60000.0', '21877616239495.52',
#        '24547089156850.34', '40000.0', '66069344800759.64', '15000.0',
#        '83176377110267.1', '12000.0', '1000000000000.0', '1000000.0',
#        '1995262314968.88', '500000.0', '2454708915685.03', '400000.0',
#        '2818382931264.45', '350000.0', '33113112148259.08', '30000.0',
#        '70794578438413.73', '14000.0', '89125093813374.4', '11000.0',
#        '100000000000000.0', '10000.0', '900.0', '6000.0', '13000.0',
# ...

# %% [markdown]
# #### Dumping the data into a CSV file

# %%
df.to_csv("bioactivity_coronavirus_data.csv", index= False)

# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount= True)
# Out:
# Mounted at /content/gdrive/

# %%
! mkdir "/content/gdrive/My Drive/Colab Notebooks/data"
# Out:
# mkdir: cannot create directory ‘/content/gdrive/My Drive/Colab Notebooks/data’: File exists

# %%
! cp bioactivity_coronavirus_data.csv "/content/gdrive/My Drive/Colab Notebooks/data"

# %%
! ls "/content/gdrive/My Drive/Colab Notebooks/data"
# Out:
# bioactivity_coronavirus_data.csv
# bioactivity_coronavirus_pIC50_data.csv
# bioactivity_coronavirus_preprocessed_data.csv

# %%
# !ls
# Out:
# bioactivity_coronavirus_data.csv
# coronavirus_bioactivity_data_pIC50_pubchem.csv
# coronavirus_bioactivity_data_pIC50_pubchem.csv.1
# coronavirus_bioactivity_data_pIC50_pubchem.csv.2
# coronavirus_bioactivity_data_pIC50_pubchem.csv.3
# drive
# gdrive
# sample_data

# %% [markdown]
# #### Look at the bioactivity data that we just have created

# %%
! head bioactivity_coronavirus_data.csv
# Out:
# activity_comment,activity_id,activity_properties,assay_chembl_id,assay_description,assay_type,assay_variant_accession,assay_variant_mutation,bao_endpoint,bao_format,bao_label,canonical_smiles,data_validity_comment,data_validity_description,document_chembl_id,document_journal,document_year,ligand_efficiency,molecule_chembl_id,molecule_pref_name,parent_molecule_chembl_id,pchembl_value,potential_duplicate,qudt_units,record_id,relation,src_id,standard_flag,standard_relation,standard_text_value,standard_type,standard_units,standard_upper_value,standard_value,target_chembl_id,target_organism,target_pref_name,target_tax_id,text_value,toid,type,units,uo_units,upper_value,value
# ...

# %% [markdown]
# #### **Handling Missing Data**
# ##### If any compunds has missing value for the standard_value column them drop it

# %%
df2= df[df.standard_value.notna()]
df2
# Out:
#     activity_comment  activity_id  ... upper_value  value
# 0               None      1480935  ...        None    7.2
# 1               None      1480936  ...        None    9.4
# 2               None      1481061  ...        None   13.5
# 3               None      1481065  ...        None  13.11
# 4               None      1481066  ...        None    2.0
# ..               ...          ...  ...         ...    ...
# 128             None     12041507  ...        None   10.6
# 129             None     12041508  ...        None   10.1
# 130             None     12041509  ...        None   11.5
# 131             None     12041510  ...        None   10.7
# 132             None     12041511  ...        None   78.9
#
# [133 rows x 45 columns]

# %% [markdown]
# ### **Data pre-processing**
# #### **Labelling compunds as either bening active, inactive or intermediate**
# ##### The bioactivity data is in teh IC50 unit. Compunds having values of less than 1000 nM will be flaged as **active** while those greater than 10,000 nM will be considered to be **inactive**. Compunds havig values in between 1,000 and 10,000 nM will be referred to as **intermediate**

# %%
bioactivity_class=[]
for i in df2.standard_value:
  if float(i) >= 10000:
    bioactivity_class.append("inactive")
  elif float(i)<= 1000:
    bioactivity_class.append("active")
  else:
    bioactivity_class.append("intermediate")

# %% [markdown]
# #### Iterate the molecule_chembl_id

# %%
df2.molecule_chembl_id
# Out:
# 0       CHEMBL187579
# 1       CHEMBL188487
# 2       CHEMBL185698
# 3       CHEMBL426082
# 4       CHEMBL187717
#            ...
# 128    CHEMBL2146517
# 129     CHEMBL187460
# 130     CHEMBL363535
# 131     CHEMBL227075
# 132      CHEMBL45830
# Name: molecule_chembl_id, Length: 133, dtype: object

# %%
mol_cid=[]
for i in df2.molecule_chembl_id:
  mol_cid.append(i)
mol_cid
# Out:
# ['CHEMBL187579',
#  'CHEMBL188487',
#  'CHEMBL185698',
#  'CHEMBL426082',
#  'CHEMBL187717',
#  'CHEMBL365134',
#  'CHEMBL187598',
#  'CHEMBL190743',
#  'CHEMBL365469',
#  'CHEMBL188983',
#  'CHEMBL191575',
#  'CHEMBL370923',
#  'CHEMBL194398',
#  'CHEMBL196635',
#  'CHEMBL209287',
#  'CHEMBL358279',
#  'CHEMBL348660',
#  'CHEMBL379727',
#  'CHEMBL210525',
#  'CHEMBL148483',
#  'CHEMBL383725',
#  'CHEMBL118596',
#  'CHEMBL208732',
#  'CHEMBL208732',
#  'CHEMBL210146',
#  'CHEMBL210146',
#  'CHEMBL207458',
#  'CHEMBL207458',
#  'CHEMBL207484',
#  'CHEMBL207484',
#  'CHEMBL207207',
#  'CHEMBL207207',
#  'CHEMBL210487',
#  'CHEMBL210487',
#  'CHEMBL380470',
#  'CHEMBL380470',
#  'CHEMBL210612',
#  'CHEMBL210612',
#  'CHEMBL209667',
#  'CHEMBL209667',
#  'CHEMBL210097',
#  'CHEMBL210097',
#  'CHEMBL378674',
#  'CHEMBL378674',
#  'CHEMBL210216',
#  'CHEMBL210216',
#  'CHEMBL210195',
#  'CHEMBL210195',
#  'CHEMBL210437',
#  'CHEMBL210437',
#  'CHEMBL378677',
#  'CHEMBL378677',
# ...

# %% [markdown]
# #### **Iterate canonical_smiles to a list**
#
# #### **What is Smiles?**
# ##### The term SMILES refers to a line notation for encoding molecular structures and specific instances should strictly be called SMILES strings. However, the term SMILES is also commonly used to refer to both a single SMILES string and a number of SMILES strings; the exact meaning is usually apparent from the context. The terms "canonical" and "isomeric" can lead to some confusion when applied to SMILES. The terms describe different attributes of SMILES strings and are not mutually exclusive.

# %%
canonical_smiles=[]
for i in df2.canonical_smiles:
  canonical_smiles.append(i)

# %% [markdown]
# #### **Iterate standard_value to a list**

# %%
standard_value=[]
for i in df2.standard_value:
  standard_value.append(i)

# %% [markdown]
# ### **Alterative Method**

# %%
selection=['molecule_chembl_id','canonical_smiles', 'standard_value']
df3=df2[selection]
df3
# Out:
#     molecule_chembl_id  ... standard_value
# 0         CHEMBL187579  ...         7200.0
# 1         CHEMBL188487  ...         9400.0
# 2         CHEMBL185698  ...        13500.0
# 3         CHEMBL426082  ...        13110.0
# 4         CHEMBL187717  ...         2000.0
# ..                 ...  ...            ...
# 128      CHEMBL2146517  ...        10600.0
# 129       CHEMBL187460  ...        10100.0
# 130       CHEMBL363535  ...        11500.0
# 131       CHEMBL227075  ...        10700.0
# 132        CHEMBL45830  ...        78900.0
#
# [133 rows x 3 columns]

# %% [markdown]
# #### **Made a dataframe out of the 4 lists**

# %%
data_tuples=list(zip(mol_cid, canonical_smiles, bioactivity_class, standard_value))
df3= pd.DataFrame(data_tuples, columns=['molecule_chembl_id', 'canonical_smiles', 'bioactivity_class', 'standard_value'])
df3
# Out:
#     molecule_chembl_id  ... standard_value
# 0         CHEMBL187579  ...         7200.0
# 1         CHEMBL188487  ...         9400.0
# 2         CHEMBL185698  ...        13500.0
# 3         CHEMBL426082  ...        13110.0
# 4         CHEMBL187717  ...         2000.0
# ..                 ...  ...            ...
# 128      CHEMBL2146517  ...        10600.0
# 129       CHEMBL187460  ...        10100.0
# 130       CHEMBL363535  ...        11500.0
# 131       CHEMBL227075  ...        10700.0
# 132        CHEMBL45830  ...        78900.0
#
# [133 rows x 4 columns]

# %%
pd.concat([df3,pd.Series(bioactivity_class)],axis=1)
# Out:
#     molecule_chembl_id  ...             0
# 0         CHEMBL187579  ...  intermediate
# 1         CHEMBL188487  ...  intermediate
# 2         CHEMBL185698  ...      inactive
# 3         CHEMBL426082  ...      inactive
# 4         CHEMBL187717  ...  intermediate
# ..                 ...  ...           ...
# 128      CHEMBL2146517  ...      inactive
# 129       CHEMBL187460  ...      inactive
# 130       CHEMBL363535  ...      inactive
# 131       CHEMBL227075  ...      inactive
# 132        CHEMBL45830  ...      inactive
#
# [133 rows x 5 columns]

# %% [markdown]
# #### **Save the pre-processed bioactivity data as csv file**

# %%
df3.to_csv('bioactivity_coronavirus_preprocessed_data.csv',index=False)

# %%
# !ls
# Out:
# bioactivity_coronavirus_data.csv
# bioactivity_coronavirus_preprocessed_data.csv
# coronavirus_bioactivity_data_pIC50_pubchem.csv
# coronavirus_bioactivity_data_pIC50_pubchem.csv.1
# coronavirus_bioactivity_data_pIC50_pubchem.csv.2
# coronavirus_bioactivity_data_pIC50_pubchem.csv.3
# drive
# gdrive
# sample_data

# %% [markdown]
# #### **Copy the data to google drive**

# %%
! cp bioactivity_coronavirus_preprocessed_data.csv "/content/gdrive/My Drive/Colab Notebooks/data"

# %%
ls
# Out:
# ls: cannot access 'drive': Transport endpoint is not connected
# bioactivity_coronavirus_data.csv
# bioactivity_coronavirus_preprocessed_data.csv
# coronavirus_bioactivity_data_pIC50_pubchem.csv
# coronavirus_bioactivity_data_pIC50_pubchem.csv.1
# coronavirus_bioactivity_data_pIC50_pubchem.csv.2
# coronavirus_bioactivity_data_pIC50_pubchem.csv.3
# drive/
# gdrive/
# sample_data/

# %% [markdown]
# ## **Exploratory data analysis**
# ##### Performing Descriptor Calculation and EDA
# ##### we will use molecule name and smiles to computer molecular descriptors.
#
# #### **What is molecular descriptor?**
# ##### Molecular descriptors can be defined as mathematical representations of molecules' properties that are generated by algorithms. The numerical values of molecular descriptors are used to quantitatively describe the physical and chemical information of the molecules
# ![440801_1_En_1_Fig2_HTML.png](data:image/png;base64,...)

# %% [markdown]
# ##### **What is RDkit?**
# ###### Open-Source Cheminformatics Software
# [link text](https://www.rdkit.org/)

# %%
! wget https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.2-Linux-x86_64.sh
! chmod +x Miniconda3-py37_4.8.2-Linux-x86_64.sh
! bash ./Miniconda3-py37_4.8.2-Linux-x86_64.sh -b -f -p /usr/local
! conda install -c rdkit rdkit -y
import sys
sys.path.append('/usr/local/lib/python3.7/site-packages/')
# Out:
# --2021-06-08 16:27:14--  https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.2-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.131.3, 104.16.130.3, 2606:4700::6810:8303, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.131.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 85055499 (81M) [application/x-sh]
# Saving to: ‘Miniconda3-py37_4.8.2-Linux-x86_64.sh’
#
# Miniconda3-py37_4.8 100%[===================>]  81.12M   183MB/s    in 0.4s
#
# 2021-06-08 16:27:15 (183 MB/s) - ‘Miniconda3-py37_4.8.2-Linux-x86_64.sh’ saved [85055499/85055499]
#
# PREFIX=/usr/local
# Unpacking payload ...
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - _libgcc_mutex==0.1=main
#     - asn1crypto==1.3.0=py37_0
#     - ca-certificates==2020.1.1=0
#     - certifi==2019.11.28=py37_0
#     - cffi==1.14.0=py37h2e261b9_0
#     - chardet==3.0.4=py37_1003
# ...

# %% [markdown]
#  **Calculate Lipinski descriptors**
# ###### Christopher Lipinski, a scientist at Pfizer, came up with a set of rule-of-thumb for evaluating the druglikeness of compounds. Such druglikeness is based on the Absorption, Distribution, Metabolism and Excretion (ADME) that is also known as the pharmacokinetic profile. Lipinski analyzed all orally active FDA-approved drugs in the formulation of what is to be known as the Rule-of-Five or Lipinski's Rule.
#
# ###### The Lipinski's Rule stated the following:
#
# -Molecular weight < 500 Dalton
#
# -Octanol-water partition coefficient (LogP) < 5
#
# -Hydrogen bond donors < 5
#
# -Hydrogen bond acceptors < 10
#
# ##### **Octanol-water partition coefficient**
# ###### The n-octanol-water partition coefficient, Kow is a partition coefficient for the two-phase system consisting of n-octanol and water. Kow is also frequently referred to by the symbol P, especially in the English literature.

# %%
import numpy as np
from rdkit import Chem
from rdkit.Chem import Descriptors, Lipinski

# %% [markdown]
# #### **Calculate Descriptors**
# ###### **What is Molecular Descriptors**
# ###### Molecular descriptors can be defined as mathematical representations of molecules’ properties that are generated by algorithms. The numerical values of molecular descriptors are used to quantitatively describe the physical and chemical information of the molecules

# %%
def lipinski(smiles, verbose=False):

    moldata= []
    for elem in smiles:
        mol=Chem.MolFromSmiles(elem) 
        moldata.append(mol)
       
    baseData= np.arange(1,1)
    i=0  
    for mol in moldata:        
       
        desc_MolWt = Descriptors.MolWt(mol)
        desc_MolLogP = Descriptors.MolLogP(mol)
        desc_NumHDonors = Lipinski.NumHDonors(mol)
        desc_NumHAcceptors = Lipinski.NumHAcceptors(mol)
           
        row = np.array([desc_MolWt,
                        desc_MolLogP,
                        desc_NumHDonors,
                        desc_NumHAcceptors])   
    
        if(i==0):
            baseData=row
        else:
            baseData=np.vstack([baseData, row])
        i=i+1      
    
    columnNames=["MW","LogP","NumHDonors","NumHAcceptors"]   
    descriptors = pd.DataFrame(data=baseData,columns=columnNames)
    
    return descriptors

# %%
df3_lipinski= lipinski(df.canonical_smiles)

# %% [markdown]
# ##### **Combine Dataframes**
#
# ##### **MW**: size of the molecule
# ##### **LopP**: Solubility

# %%
df3_lipinski
# Out:
#         MW  LogP  NumHDonors  NumHAcceptors
# 0   281.27  1.89        0.00           5.00
# 1   415.59  3.81        0.00           2.00
# 2   421.19  2.66        0.00           4.00
# 3   293.35  3.63        0.00           3.00
# 4   338.34  3.54        0.00           5.00
# ..     ...   ...         ...            ...
# 128 338.36  3.40        0.00           5.00
# 129 296.37  3.44        0.00           3.00
# 130 276.29  4.10        0.00           3.00
# 131 278.31  3.29        0.00           3.00
# 132 282.38  4.11        0.00           2.00
#
# [133 rows x 4 columns]

# %%
df3
# Out:
#     molecule_chembl_id  ... standard_value
# 0         CHEMBL187579  ...         7200.0
# 1         CHEMBL188487  ...         9400.0
# 2         CHEMBL185698  ...        13500.0
# 3         CHEMBL426082  ...        13110.0
# 4         CHEMBL187717  ...         2000.0
# ..                 ...  ...            ...
# 128      CHEMBL2146517  ...        10600.0
# 129       CHEMBL187460  ...        10100.0
# 130       CHEMBL363535  ...        11500.0
# 131       CHEMBL227075  ...        10700.0
# 132        CHEMBL45830  ...        78900.0
#
# [133 rows x 4 columns]

# %% [markdown]
# ##### **We wanted to have the standard_value and bioactivity_class column with our lipinski dataframe. So, we are going to combine them both**

# %%
df3_combined=pd.concat([df3,df3_lipinski],axis=1)

df3_combined
# Out:
#     molecule_chembl_id  ... NumHAcceptors
# 0         CHEMBL187579  ...          5.00
# 1         CHEMBL188487  ...          2.00
# 2         CHEMBL185698  ...          4.00
# 3         CHEMBL426082  ...          3.00
# 4         CHEMBL187717  ...          5.00
# ..                 ...  ...           ...
# 128      CHEMBL2146517  ...          5.00
# 129       CHEMBL187460  ...          3.00
# 130       CHEMBL363535  ...          3.00
# 131       CHEMBL227075  ...          3.00
# 132        CHEMBL45830  ...          2.00
#
# [133 rows x 8 columns]

# %% [markdown]
# #### **Let's find out the distibution of IC50**
# ##### Perform a scatter plot

# %% [markdown]
# #### **Convert IC50 to pIC50**
# ##### This is a negetive logarithimic transformation. The original IC50 values have uneven distribution on the datapoints. In order to make the distribution more even we use negetive log transformation.
# ##### **To allow IC50 data to be more uniformly distributed, we will convert IC50 to the negative logarithmic scale which is essentially -log10(IC50)**.
#
# This custom function pIC50() will accept a DataFrame as input and will:
#
# * Take the IC50 values from the standard_value column and converts it from
#   nM to M by multiplying the value by 10$^{-9}$
#
# * Take the molar value and apply -log10
#
# * Delete the standard_value column and create a new pIC50 column

# %%
import numpy as np

def pIC50(input):
    pIC50 = []

    for i in input['standard_value_norm']:
        molar = i*(10**-9) # Converts nM to M
        pIC50.append(-np.log10(molar))

    input['pIC50'] = pIC50
    x = input.drop('standard_value_norm', 1)
        
    return x

# %%
df3_combined["standard_value"] = df3_combined.standard_value.astype(float)  ## convert object datatype to float
df3_combined.standard_value.describe()
# Out:
# count               133.00
# mean      8017925993202.99
# std      33448884317724.05
# min                  50.00
# 25%               10700.00
# 50%               23500.00
# 75%              300000.00
# max     331131121482590.75
# Name: standard_value, dtype: float64

# %% [markdown]
# ##### **Compare the Scatter plot of IC50 vs pIC50**

# %% [markdown]
# ##### **Values greater than 100,000,000 will be fixed at 100,000,000 otherwise the negative logarithmic value will become negative.**

# %%
-np.log10((10**-9)* 100000000)
# Out:
# 1.0

# %%
-np.log10((10** -9)* 10000000000)
# Out:
# -1.0

# %% [markdown]
# ##### We will keep the cap value to 10000000000 by creating a custom function. This fuction read through the indevidual value of the standard value column and if the value is>10000000000 it will cap the value to 100M

# %%
def norm_value(input):
    norm = []

    for i in input['standard_value']:
        if i > 100000000:
          i = 100000000
        norm.append(i)

    input['standard_value_norm'] = norm
    x = input.drop('standard_value', 1)
        
    return x

# %% [markdown]
# **Let's normalized the standard_value column with the help of norm_value() function**

# %%
df3_norm = norm_value(df3_combined)
df3_norm
# Out:
#     molecule_chembl_id  ... standard_value_norm
# 0         CHEMBL187579  ...             7200.00
# 1         CHEMBL188487  ...             9400.00
# 2         CHEMBL185698  ...            13500.00
# 3         CHEMBL426082  ...            13110.00
# 4         CHEMBL187717  ...             2000.00
# ..                 ...  ...                 ...
# 128      CHEMBL2146517  ...            10600.00
# 129       CHEMBL187460  ...            10100.00
# 130       CHEMBL363535  ...            11500.00
# 131       CHEMBL227075  ...            10700.00
# 132        CHEMBL45830  ...            78900.00
#
# [133 rows x 8 columns]

# %%
df3_norm.standard_value_norm.describe()
# Out:
# count         133.00
# mean     21101642.95
# std      40897141.03
# min            50.00
# 25%         10700.00
# 50%         23500.00
# 75%        300000.00
# max     100000000.00
# Name: standard_value_norm, dtype: float64

# %% [markdown]
# #### **Delete IC50 and create pIC50**

# %%
df3_final=pIC50(df3_norm)
df3_final
# Out:
#     molecule_chembl_id  ... pIC50
# 0         CHEMBL187579  ...  5.14
# 1         CHEMBL188487  ...  5.03
# 2         CHEMBL185698  ...  4.87
# 3         CHEMBL426082  ...  4.88
# 4         CHEMBL187717  ...  5.70
# ..                 ...  ...   ...
# 128      CHEMBL2146517  ...  4.97
# 129       CHEMBL187460  ...  5.00
# 130       CHEMBL363535  ...  4.94
# 131       CHEMBL227075  ...  4.97
# 132        CHEMBL45830  ...  4.10
#
# [133 rows x 8 columns]

# %%
df3_final.pIC50.describe()
# Out:
# count   133.00
# mean      4.06
# std       1.78
# min       1.00
# 25%       3.52
# 50%       4.63
# 75%       4.97
# max       7.30
# Name: pIC50, dtype: float64

# %% [markdown]
# #### **Removing the 'Intermediate' bioactivity class**

# %%
df3_final
# Out:
#     molecule_chembl_id  ... pIC50
# 0         CHEMBL187579  ...  5.14
# 1         CHEMBL188487  ...  5.03
# 2         CHEMBL185698  ...  4.87
# 3         CHEMBL426082  ...  4.88
# 4         CHEMBL187717  ...  5.70
# ..                 ...  ...   ...
# 128      CHEMBL2146517  ...  4.97
# 129       CHEMBL187460  ...  5.00
# 130       CHEMBL363535  ...  4.94
# 131       CHEMBL227075  ...  4.97
# 132        CHEMBL45830  ...  4.10
#
# [133 rows x 8 columns]

# %%
df_2class = df3_final[df3_final.bioactivity_class != 'intermediate']
df_2class
# Out:
#     molecule_chembl_id  ... pIC50
# 2         CHEMBL185698  ...  4.87
# 3         CHEMBL426082  ...  4.88
# 5         CHEMBL365134  ...  6.01
# 7         CHEMBL190743  ...  6.02
# 8         CHEMBL365469  ...  4.95
# ..                 ...  ...   ...
# 128      CHEMBL2146517  ...  4.97
# 129       CHEMBL187460  ...  5.00
# 130       CHEMBL363535  ...  4.94
# 131       CHEMBL227075  ...  4.97
# 132        CHEMBL45830  ...  4.10
#
# [119 rows x 8 columns]

# %% [markdown]
# #### **Download dataset that contains pIC50**

# %%
df_2class.to_csv("bioactivity_coronavirus_pIC50_data.csv", index= False)

# %%
! mkdir "/content/gdrive/My Drive/Colab Notebooks/data"
# Out:
# mkdir: cannot create directory ‘/content/gdrive/My Drive/Colab Notebooks/data’: File exists

# %%
! cp bioactivity_coronavirus_pIC50_data.csv "/content/gdrive/My Drive/Colab Notebooks/data"

# %%
 ls "/content/gdrive/My Drive/Colab Notebooks/data"
# Out:
# bioactivity_coronavirus_data.csv
# bioactivity_coronavirus_pIC50_data.csv
# bioactivity_coronavirus_preprocessed_data.csv

# %%
ls
# Out:
# ls: cannot access 'drive': Transport endpoint is not connected
# bioactivity_coronavirus_data.csv
# bioactivity_coronavirus_pIC50_data.csv
# bioactivity_coronavirus_preprocessed_data.csv
# coronavirus_bioactivity_data_pIC50_pubchem.csv
# coronavirus_bioactivity_data_pIC50_pubchem.csv.1
# coronavirus_bioactivity_data_pIC50_pubchem.csv.2
# coronavirus_bioactivity_data_pIC50_pubchem.csv.3
# drive/
# gdrive/
# Miniconda3-py37_4.8.2-Linux-x86_64.sh*
# sample_data/

# %% [markdown]
# #### **Chemical Space Analysis via Lipinski descriptors**

# %%
import seaborn as sns
sns.set(style='ticks')
import matplotlib.pyplot as plt

# %% [markdown]
# #### **Frequency plot of the 2 bioactive classes**

# %%
plt.figure(figsize=(5.5, 5.5))
sns.countplot(x='bioactivity_class', data=df_2class, edgecolor='black')
plt.xlabel('Bioactivity class', fontsize=14, fontweight='bold')
plt.ylabel('Frequency', fontsize=14, fontweight='bold')

plt.savefig('plot-bioactivity_class.pdf')

# %% [markdown]
# #### **Scatter plot of MW VS LogP**

# %%
plt.figure(figsize=(5.5,5.5))
sns.scatterplot(x='MW', y='LogP', data=df_2class, hue='bioactivity_class', size='pIC50', edgecolor='black', alpha=0.7)
plt.xlabel('MW', fontsize=15, fontweight='bold')
plt.ylabel('LogP', fontsize=15, fontweight='bold')
plt.legend(bbox_to_anchor=(1.05,1), loc=2, borderaxespad=0)
plt.savefig('plot_MW_vs_LogP.pdf')

# %% [markdown]
# **Box Plot**
#
# **pIC50 value**

# %%
plt.figure(figsize=(5.5,5.5))
sns.boxplot(x='bioactivity_class', y='pIC50', data=df_2class)
plt.xlabel('Bioactivity Class', fontsize=14, fontweight='bold')
plt.ylabel('pIC50 value', fontsize=14, fontweight='bold')
plt.savefig('plot_IC50.pdf')

# %% [markdown]
# #### **Statistical analysis**
#
# #### **Mann-Whitney U Test**
# ##### What is Mann-whitney U test?
# ##### The Mann-Whitney U test is used to compare differences between two independent groups when the dependent variable is either ordinal or continuous, but not normally distributed. For example, you could use the Mann-Whitney U test to understand whether attitudes towards pay discrimination, where attitudes are measured on an ordinal scale, differ based on gender (i.e., your dependent variable would be "attitudes towards pay discrimination" and your independent variable would be "gender", which has two groups: "male" and "female"). Alternately, you could use the Mann-Whitney U test to understand whether salaries, measured on a continuous scale, differed based on educational level (i.e., your dependent variable would be "salary" and your independent variable would be "educational level", which has two groups: "high school" and "university"). The Mann-Whitney U test is often considered the nonparametric alternative to the independent t-test although this is not always the case.
# ![identical-shape-distributions.png](data:image/png;base64,...)

# %%
def mannwhitney(descriptor, verbose=False):
  from numpy.random import seed
  from numpy.random import randn
  from scipy.stats import mannwhitneyu

# seed the random number generator
  seed(1)

# actives and inactives
  selection = [descriptor, 'bioactivity_class']
  df = df_2class[selection]
  active = df[df.bioactivity_class == 'active']
  active = active[descriptor]

  selection = [descriptor, 'bioactivity_class']
  df = df_2class[selection]
  inactive = df[df.bioactivity_class == 'inactive']
  inactive = inactive[descriptor]

# compare samples
  stat, p = mannwhitneyu(active, inactive)
  #print('Statistics=%.3f, p=%.3f' % (stat, p))
  # interpret
  alpha = 0.05
  if p > alpha:
    interpretation = 'Same distribution (fail to reject H0)'
  else:
    interpretation = 'Different distribution (reject H0)'
  
  results = pd.DataFrame({'Descriptor':descriptor,
                          'Statistics':stat,
                          'p':p,
                          'alpha':alpha,
                          'Interpretation':interpretation}, index=[0])
  filename = 'mannwhitneyu_' + descriptor + '.csv'
  results.to_csv(filename)

  return results

# %%
mannwhitney('pIC50')
# Out:
#   Descriptor  Statistics    p  alpha                      Interpretation
# 0      pIC50        0.00 0.00   0.05  Different distribution (reject H0)

# %% [markdown]
# **MW**

# %%
plt.figure(figsize=(5.5,5.5))
sns.boxplot(x='bioactivity_class', y='MW', data=df_2class)
plt.xlabel('Bioactivity class', fontsize=14, fontweight='bold')
plt.ylabel('MW', fontsize=15, fontweight='bold')
plt.savefig('plot_MW.pdf')

# %%
mannwhitney('MW')
# Out:
#   Descriptor  Statistics    p  alpha                      Interpretation
# 0         MW      409.50 0.00   0.05  Different distribution (reject H0)

# %% [markdown]
# **LogP**

# %%
plt.figure(figsize=(5.5,5.5))
sns.boxplot(x='bioactivity_class', y='LogP', data=df_2class)
plt.xlabel('Bioactivity class', fontsize=15, fontweight='bold')
plt.ylabel('LogP', fontsize=15, fontweight='bold')

plt.savefig('plot_LogP.pdf')

# %%
mannwhitney('LogP')
# Out:
#   Descriptor  Statistics    p  alpha                         Interpretation
# 0       LogP      712.50 0.30   0.05  Same distribution (fail to reject H0)

# %% [markdown]
# **NumHDonors**

# %%
plt.figure(figsize=(5.5,5.5))
sns.boxplot(x='bioactivity_class', y='NumHDonors', data=df_2class)
plt.xlabel('Bioactivity Class', fontsize=14, fontweight='bold')
plt.ylabel('NumHDonors', fontsize=15, fontweight='bold')

plt.savefig('plot_NumHdonors.pdf')

# %%
mannwhitney('NumHDonors')
# Out:
#    Descriptor  Statistics    p  alpha                      Interpretation
# 0  NumHDonors      299.50 0.00   0.05  Different distribution (reject H0)

# %% [markdown]
# **NumHAcceptor**

# %%
plt.figure(figsize=(5.5, 5.5))
sns.boxplot(x='bioactivity_class', y='NumHAcceptors', data=df_2class)
plt.xlabel('Bioactivity clsss', fontsize=15, fontweight='bold')
plt.ylabel('NumHAcceptors', fontsize=15, fontweight='bold')
plt.savefig('plot)_NumHAccrptor.pdf')

# %%
mannwhitney('NumHAcceptors')
# Out:
#       Descriptor  Statistics    p  alpha                      Interpretation
# 0  NumHAcceptors      415.00 0.00   0.05  Different distribution (reject H0)

# %% [markdown]
# #### **Interpretation of the statistical analysis**
#
# ##### **Box Plots**
# ##### **pIC50 values**
# ###### Taking a look at pIC50 values, the actives and inactives displayed statistically significant difference, which is to be expected since threshold values (IC50 < 1,000 nM = Actives while IC50 > 10,000 nM = Inactives, corresponding to pIC50 > 6 = Actives and pIC50 < 5 = Inactives) were used to define actives and inactives
# #### **Lipinski's descriptors**
# #### Of the 4 Lipinski's descriptors (MW, LogP, NumHDonors and NumHAcceptors), only LogP exhibited no difference between the actives and inactives while the other 3 descriptors (MW, NumHDonors and NumHAcceptors) shows statistically significant difference between actives and inactives.

# %% [markdown]
# ##### **Generate Zip files**

# %%
! zip -r results.zip . -i *.csv *.pdf
# Out:
# Scanning files
# 	zip warning: name not matched: drive
# .  adding: mannwhitneyu_pIC50.csv (deflated 10%)
#   adding: plot_IC50.pdf (deflated 37%)
#   adding: plot_NumHdonors.pdf (deflated 37%)
#   adding: plot)_NumHAccrptor.pdf (deflated 37%)
#   adding: mannwhitneyu_LogP.csv (deflated 7%)
#   adding: plot_MW_vs_LogP.pdf (deflated 15%)
#   adding: mannwhitneyu_NumHAcceptors.csv (deflated 12%)
#   adding: mannwhitneyu_NumHDonors.csv (deflated 9%)
#   adding: plot_LogP.pdf (deflated 37%)
#   adding: bioactivity_coronavirus_data.csv (deflated 90%)
#   adding: bioactivity_coronavirus_preprocessed_data.csv (deflated 80%)
#   adding: plot-bioactivity_class.pdf (deflated 38%)
#   adding: mannwhitneyu_MW.csv (deflated 9%)
#   adding: plot_MW.pdf (deflated 38%)
#   adding: bioactivity_coronavirus_pIC50_data.csv (deflated 77%)
#   adding: coronavirus_bioactivity_data_pIC50_pubchem.csv (deflated 95%)

# %% [markdown]
# #### **Descriptor calculation and Dataset Preparation**

# %% [markdown]
# ####  **Download PaDEL Descriptor Tool**
# ##### PaDEL-Descriptor is a software for calculating molecular descriptors and fingerprints. The software currently calculates 797 descriptors (663 1D, 2D descriptors, and 134 3D descriptors) and 10 types of fingerprints. These descriptors and fingerprints are calculated mainly using The Chemistry Development Kit. Some additional descriptors and fingerprints were added, which include atom type electrotopological state descriptors, McGowan volume, molecular linear free energy relation descriptors, ring counts, count of chemical substructures identified by Laggner, and binary fingerprints and count of chemical substructures identified by Klekota and Roth.

# %%
! wget https://github.com/dataprofessor/bioinformatics/raw/master/padel.zip
! wget https://github.com/dataprofessor/bioinformatics/raw/master/padel.sh
# Out:
# --2021-06-08 16:28:39--  https://github.com/dataprofessor/bioinformatics/raw/master/padel.zip
# Resolving github.com (github.com)... 140.82.121.3
# Connecting to github.com (github.com)|140.82.121.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/dataprofessor/bioinformatics/master/padel.zip [following]
# --2021-06-08 16:28:39--  https://raw.githubusercontent.com/dataprofessor/bioinformatics/master/padel.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 25768637 (25M) [application/zip]
# Saving to: ‘padel.zip’
#
# padel.zip           100%[===================>]  24.57M  84.2MB/s    in 0.3s
#
# 2021-06-08 16:28:40 (84.2 MB/s) - ‘padel.zip’ saved [25768637/25768637]
#
# ...

# %%
! unzip padel.zip
# Out:
# Archive:  padel.zip
#    creating: PaDEL-Descriptor/
#   inflating: __MACOSX/._PaDEL-Descriptor
#   inflating: PaDEL-Descriptor/MACCSFingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._MACCSFingerprinter.xml
#   inflating: PaDEL-Descriptor/AtomPairs2DFingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._AtomPairs2DFingerprinter.xml
#   inflating: PaDEL-Descriptor/EStateFingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._EStateFingerprinter.xml
#   inflating: PaDEL-Descriptor/Fingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._Fingerprinter.xml
#   inflating: PaDEL-Descriptor/.DS_Store
#   inflating: __MACOSX/PaDEL-Descriptor/._.DS_Store
#    creating: PaDEL-Descriptor/license/
#   inflating: __MACOSX/PaDEL-Descriptor/._license
#   inflating: PaDEL-Descriptor/KlekotaRothFingerprintCount.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._KlekotaRothFingerprintCount.xml
#   inflating: PaDEL-Descriptor/config
# ...

# %% [markdown]
# #### **Load Bioactivity Data**
# ##### I am going to use bioactivity_data_3class_pIC50.csv file that essentially contain the pIC50 values.

# %%
! wget https://raw.githubusercontent.com/Sangramjit/coronavisus_drug_discovery/main/bioactivity_coronavirus_pIC50_data.csv
# Out:
# --2021-06-08 16:28:41--  https://raw.githubusercontent.com/Sangramjit/coronavisus_drug_discovery/main/bioactivity_coronavirus_pIC50_data.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 15005 (15K) [text/plain]
# Saving to: ‘bioactivity_coronavirus_pIC50_data.csv.1’
#
# bioactivity_coronav 100%[===================>]  14.65K  --.-KB/s    in 0s
#
# 2021-06-08 16:28:42 (114 MB/s) - ‘bioactivity_coronavirus_pIC50_data.csv.1’ saved [15005/15005]

# %%
import pandas as pd
df4=pd.read_csv('bioactivity_coronavirus_pIC50_data.csv')
df4
# Out:
#     molecule_chembl_id  ... pIC50
# 0         CHEMBL185698  ...  4.87
# 1         CHEMBL426082  ...  4.88
# 2         CHEMBL365134  ...  6.01
# 3         CHEMBL190743  ...  6.02
# 4         CHEMBL365469  ...  4.95
# ..                 ...  ...   ...
# 114      CHEMBL2146517  ...  4.97
# 115       CHEMBL187460  ...  5.00
# 116       CHEMBL363535  ...  4.94
# 117       CHEMBL227075  ...  4.97
# 118        CHEMBL45830  ...  4.10
#
# [119 rows x 8 columns]

# %% [markdown]
# #### **Select canonical_smile and molecule_chembl_id**

# %%
selection=['canonical_smiles','molecule_chembl_id']
df4_selection=df4[selection] ## subset the data
df4_selection.to_csv('molecule.smi',sep='\t',index=False, header=False)

# %%
! cat molecule.smi | head -10
# Out:
# O=C1C(=O)N(CC2COc3ccccc3O2)c2ccc(I)cc21	CHEMBL185698
# O=C1C(=O)N(Cc2cc3ccccc3s2)c2ccccc21	CHEMBL426082
# O=C1C(=O)N(Cc2cc3ccccc3s2)c2c(Br)cccc21	CHEMBL365134
# O=C1C(=O)N(Cc2cc3ccccc3s2)c2ccc(I)cc21	CHEMBL190743
# O=C1C(=O)N(Cc2cc3ccccc3s2)c2cccc(Cl)c21	CHEMBL365469
# O=C1C(=O)N(C/C=C/c2cc3ccccc3s2)c2ccc(I)cc21	CHEMBL188983
# O=C(Nc1ccc(Cl)cc1)c1ccc(CN2C(=O)C(=O)c3cc(I)ccc32)s1	CHEMBL191575
# O=C1C(=O)N(Cc2ccc(C(=O)N3CCCCC3)s2)c2ccc(I)cc21	CHEMBL370923
# CCOC(=O)/C=C/[C@H](C[C@@H]1CCNC1=O)NC(=O)[C@@H](CC(=O)[C@@H](NC(=O)c1cc(C)on1)C(C)C)Cc1ccccc1	CHEMBL194398
# CCOC(=O)/C=C/[C@H](C[C@@H]1CCNC1=O)NC(=O)[C@H](CC=C(C)C)CC(=O)[C@@H](NC(=O)c1cc(C)on1)C(C)C	CHEMBL196635

# %%
! cat molecule.smi | wc -l  ## How many lins of molecules do we have
# Out:
# 119

# %% [markdown]
# ### **Calculate Fingerprint descriptors**
#
# #### Fingerprints or descriptors are an abstract representation of certain structural features of a molecule. These descriptors may represent a structural key within a molecule

# %% [markdown]
# **Calculate PaDEL descriptors**

# %%
! cat padel.sh
# Out:
# java -Xms1G -Xmx1G -Djava.awt.headless=true -jar ./PaDEL-Descriptor/PaDEL-Descriptor.jar -removesalt -standardizenitro -fingerprints -descriptortypes ./PaDEL-Descriptor/PubchemFingerprinter.xml -dir ./ -file descriptors_output.csv

# %%
! bash padel.sh
# Out:
# Jun 08, 2021 4:28:45 PM libpadeldescriptor.libPaDELDescriptorMaster hasNextJob
# SEVERE: drive
# java.io.FileNotFoundException: ./drive (Transport endpoint is not connected)
# 	at java.base/java.io.FileInputStream.open0(Native Method)
# 	at java.base/java.io.FileInputStream.open(FileInputStream.java:219)
# 	at java.base/java.io.FileInputStream.<init>(FileInputStream.java:157)
# 	at libpadeldescriptor.IteratingPaDELReader.<init>(Unknown Source)
# 	at libpadeldescriptor.libPaDELDescriptorMaster.hasNextJob(Unknown Source)
# 	at libpadeldescriptor.libPaDELDescriptorMaster.hasNextJob(Unknown Source)
# 	at libpadeldescriptor.libPaDELDescriptorMaster.hasNextJob(Unknown Source)
# 	at libpadeldescriptor.libPaDELDescriptorMaster.hasNextJob(Unknown Source)
# 	at libpadeldescriptor.libPaDELDescriptorMaster.hasNextJob(Unknown Source)
# 	at libpadeldescriptor.libPaDELDescriptorMaster.hasNextJob(Unknown Source)
# 	at libpadeldescriptor.libPaDELDescriptorMaster.hasNextJob(Unknown Source)
# ...

# %%
ls -l
# Out:
# ls: cannot access 'drive': Transport endpoint is not connected
# total 117260
# -rw-r--r-- 1 root root    70334 Jun  8 16:27  bioactivity_coronavirus_data.csv
# -rw-r--r-- 1 root root    15005 Jun  8 16:28  bioactivity_coronavirus_pIC50_data.csv
# -rw-r--r-- 1 root root    15005 Jun  8 16:28  bioactivity_coronavirus_pIC50_data.csv.1
# -rw-r--r-- 1 root root    10578 Jun  8 16:27  bioactivity_coronavirus_preprocessed_data.csv
# -rw-r--r-- 1 root root   222748 Jun  8 14:44  coronavirus_bioactivity_data_pIC50_pubchem.csv
# -rw-r--r-- 1 root root  2792427 Jun  8 15:34  coronavirus_bioactivity_data_pIC50_pubchem.csv.1
# -rw-r--r-- 1 root root  2787771 Jun  8 15:44  coronavirus_bioactivity_data_pIC50_pubchem.csv.2
# -rw-r--r-- 1 root root  2792427 Jun  8 15:51  coronavirus_bioactivity_data_pIC50_pubchem.csv.3
# -rw-r--r-- 1 root root   222809 Jun  8 16:29  descriptors_output.csv
# d????????? ? ?    ?           ?            ?  drive/
# drwx------ 5 root root     4096 Jun  8 16:27  gdrive/
# ...

# %% [markdown]
# **Prepare X and Y data matrices**

# %% [markdown]
# **X data matrix**

# %%
df4_X=pd.read_csv('descriptors_output.csv')

# %%
df4_X
# Out:
#               Name  PubchemFP0  ...  PubchemFP879  PubchemFP880
# 0     CHEMBL426082           1  ...             0             0
# 1     CHEMBL185698           1  ...             0             0
# 2     CHEMBL190743           1  ...             0             0
# 3     CHEMBL365134           1  ...             0             0
# 4     CHEMBL365469           1  ...             0             0
# ..             ...         ...  ...           ...           ...
# 114   CHEMBL187460           1  ...             0             0
# 115  CHEMBL2146517           1  ...             0             0
# 116   CHEMBL363535           1  ...             0             0
# 117   CHEMBL227075           1  ...             0             0
# 118    CHEMBL45830           1  ...             0             0
#
# [119 rows x 882 columns]

# %% [markdown]
# #### **Delete the names because I just want the molecular features**

# %%
df4_X=df4_X.drop(columns=['Name'])
df4_X
# Out:
#      PubchemFP0  PubchemFP1  ...  PubchemFP879  PubchemFP880
# 0             1           1  ...             0             0
# 1             1           1  ...             0             0
# 2             1           1  ...             0             0
# 3             1           1  ...             0             0
# 4             1           1  ...             0             0
# ..          ...         ...  ...           ...           ...
# 114           1           1  ...             0             0
# 115           1           1  ...             0             0
# 116           1           1  ...             0             0
# 117           1           1  ...             0             0
# 118           1           1  ...             0             0
#
# [119 rows x 881 columns]

# %% [markdown]
# **Y data matrix**
#
# Convert IC50 to pIC50

# %%
df4_Y=df4['pIC50']
df4_Y
# Out:
# 0     4.87
# 1     4.88
# 2     6.01
# 3     6.02
# 4     4.95
#       ...
# 114   4.97
# 115   5.00
# 116   4.94
# 117   4.97
# 118   4.10
# Name: pIC50, Length: 119, dtype: float64

# %% [markdown]
# **Combine X and Y data matrices**

# %%
dataset=pd.concat([df4_X,df4_Y], axis=1)
dataset

## Dump the whole data into csv file
dataset.to_csv('coronavirus_bioactivity_data_pIC50_pubchem.csv', index=False)

# %%
dataset
# Out:
#      PubchemFP0  PubchemFP1  PubchemFP2  ...  PubchemFP879  PubchemFP880  pIC50
# 0             1           1           0  ...             0             0   4.87
# 1             1           1           0  ...             0             0   4.88
# 2             1           1           0  ...             0             0   6.01
# 3             1           1           0  ...             0             0   6.02
# 4             1           1           0  ...             0             0   4.95
# ..          ...         ...         ...  ...           ...           ...    ...
# 114           1           1           1  ...             0             0   4.97
# 115           1           1           1  ...             0             0   5.00
# 116           1           1           0  ...             0             0   4.94
# 117           1           1           0  ...             0             0   4.97
# 118           1           1           1  ...             0             0   4.10
#
# ...

# %% [markdown]
# ### **Model Building**

# %%
pip install sklearn
# Out:
# ...
#      |████████████████████████████████| 22.3 MB 1.3 MB/s
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', OSError("(104, 'ECONNRESET')"))': /simple/scipy/
# ...
#      |████████████████████████████████| 27.4 MB 1.5 MB/s
# ...
#   Using cached threadpoolctl-2.1.0-py3-none-any.whl (12 kB)
# ...
#      |████████████████████████████████| 303 kB 71.6 MB/s
# ...
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1315 sha256=a70ea043e7e55e0c70c1408998ec908f2463113feafd5f8062156791fa6deedd
#   Stored in directory: /root/.cache/pip/wheels/46/ef/c3/157e41f5ee1372d1be90b09f74f82b10e391eaacca8f22d33e
# Successfully built sklearn
# ...

# %%
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

# %% [markdown]
# #### **Load the dataset**

# %%
! wget https://github.com/Sangramjit/coronavisus_drug_discovery/blob/main/coronavirus_bioactivity_data_pIC50_pubchem.csv
# Out:
# --2021-06-08 16:29:18--  https://github.com/Sangramjit/coronavisus_drug_discovery/blob/main/coronavirus_bioactivity_data_pIC50_pubchem.csv
# Resolving github.com (github.com)... 140.82.121.4
# Connecting to github.com (github.com)|140.82.121.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘coronavirus_bioactivity_data_pIC50_pubchem.csv.4’
#
# coronavirus_bioacti     [ <=>                ]   2.66M  --.-KB/s    in 0.07s
#
# 2021-06-08 16:29:19 (40.0 MB/s) - ‘coronavirus_bioactivity_data_pIC50_pubchem.csv.4’ saved [2787777]

# %%
df=pd.read_csv('coronavirus_bioactivity_data_pIC50_pubchem.csv')

# %% [markdown]
# **Input Features**

# %%
X=df.drop('pIC50', axis=1)
X
# Out:
#      PubchemFP0  PubchemFP1  ...  PubchemFP879  PubchemFP880
# 0             1           1  ...             0             0
# 1             1           1  ...             0             0
# 2             1           1  ...             0             0
# 3             1           1  ...             0             0
# 4             1           1  ...             0             0
# ..          ...         ...  ...           ...           ...
# 114           1           1  ...             0             0
# 115           1           1  ...             0             0
# 116           1           1  ...             0             0
# 117           1           1  ...             0             0
# 118           1           1  ...             0             0
#
# [119 rows x 881 columns]

# %% [markdown]
# ##### Each molecule will be given unique fingerprint. The unique fingerprint of the molecules help the ML model to learn from the unique properties of the molecules and then crate a model which can distinguished between active and inactive compunds.

# %%
Y=df.pIC50
Y
# Out:
# 0     4.87
# 1     4.88
# 2     6.01
# 3     6.02
# 4     4.95
#       ...
# 114   4.97
# 115   5.00
# 116   4.94
# 117   4.97
# 118   4.10
# Name: pIC50, Length: 119, dtype: float64

# %% [markdown]
# **Data Dimension**

# %%
X.shape
# Out:
# (119, 881)

# %%
Y.shape
# Out:
# (119,)

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# #### **Remove low varience features**

# %%
from sklearn.feature_selection import VarianceThreshold
selection= VarianceThreshold(threshold=(.8 * (1- .8)))
X=selection.fit_transform(X)

# %%
X.shape
# Out:
# (119, 197)

# %% [markdown]
# #### **Train and Test split(80/20)**

# %%
X_train, X_test, Y_train, Y_test=train_test_split(X,Y, test_size=0.2)

# %%
X_train.shape, Y_train.shape
# Out:
# ((95, 197), (95,))

# %%
X_test.shape, Y_test.shape
# Out:
# ((24, 197), (24,))

# %% [markdown]
# #### **Regression Model building using Random Forest**

# %%
import numpy as np
np.random.seed(100)
model=RandomForestRegressor(n_estimators=100)
model.fit(X_train, Y_train)
r2=model.score(X_test, Y_test)
r2
# Out:
# 0.5584347158485776

# %%
Y_pred=model.predict(X_test)

# %% [markdown]
# #### **Scatter plot of Experimental vs Predicted pIC50 values**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(color_codes=True)
sns.set_style('white')

ax=sns.regplot(Y_test, Y_pred, scatter_kws={'alpha':0.4})
ax.set_xlabel('Experimental pIC50', fontsize=15, fontweight='bold')
ax.set_ylabel('Predicted pIC50', fontsize=15, fontweight='bold')
ax.set_xlim(0,12)
ax.set_ylim(0,12)
ax.figure.set_size_inches(5,5)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# #### **Compare several ML algorithm for building regression model of SARS coronavirus 3C-like proteinas**

# %%
pip install lazypredict
# Out:
# ...
#   Using cached lazypredict-0.2.9-py2.py3-none-any.whl (12 kB)
# ...
#      |████████████████████████████████| 82 kB 853 kB/s
# ...
#   Using cached xgboost-1.1.1-py3-none-manylinux2010_x86_64.whl (127.6 MB)
# ...
#   Using cached pytest-5.4.3-py3-none-any.whl (248 kB)
# ...
# Processing /root/.cache/pip/wheels/a7/c1/ea/cf5bd31012e735dc1dfea3131a2d5eae7978b251083d6247bd/PyYAML-5.3.1-cp37-cp37m-linux_x86_64.whl
# ...
#   Using cached scipy-1.5.4-cp37-cp37m-manylinux1_x86_64.whl (25.9 MB)
# ...
#   Using cached tqdm-4.56.0-py2.py3-none-any.whl (72 kB)
# ...
#   Using cached lightgbm-2.3.1-py2.py3-none-manylinux1_x86_64.whl (1.2 MB)
# ...
#   Using cached scikit_learn-0.23.1-cp37-cp37m-manylinux1_x86_64.whl (6.8 MB)
# ...
#   Using cached joblib-1.0.0-py3-none-any.whl (302 kB)
# ...
#   Using cached pandas-1.0.5-cp37-cp37m-manylinux1_x86_64.whl (10.1 MB)
# ...
#   Using cached numpy-1.19.1-cp37-cp37m-manylinux2010_x86_64.whl (14.5 MB)
# ...
#      |████████████████████████████████| 97 kB 4.0 MB/s
# ...
#   Using cached pluggy-0.13.1-py2.py3-none-any.whl (18 kB)
# ...

# %%
import pandas as pd 
import seaborn as sns
from sklearn.model_selection import train_test_split
import lazypredict
from lazypredict.Supervised import LazyRegressor

# %% [markdown]
# **Loading dataset**

# %%
# !wget https://github.com/Sangramjit/coronavisus_drug_discovery/blob/main/coronavirus_bioactivity_data_pIC50_pubchem.csv
# Out:
# --2021-06-08 16:29:49--  https://github.com/Sangramjit/coronavisus_drug_discovery/blob/main/coronavirus_bioactivity_data_pIC50_pubchem.csv
# Resolving github.com (github.com)... 140.82.121.4
# Connecting to github.com (github.com)|140.82.121.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘coronavirus_bioactivity_data_pIC50_pubchem.csv.5’
#
# coronavirus_bioacti     [ <=>                ]   2.66M  --.-KB/s    in 0.07s
#
# 2021-06-08 16:29:50 (37.2 MB/s) - ‘coronavirus_bioactivity_data_pIC50_pubchem.csv.5’ saved [2787771]

# %%
df=pd.read_csv('coronavirus_bioactivity_data_pIC50_pubchem.csv')

# %%
X=df.drop('pIC50',axis=1)
Y=df.pIC50

# %% [markdown]
# **Data Preprocessing**

# %%
X.shape
# Out:
# (119, 881)

# %%
Y.shape
# Out:
# (119,)

# %%
from sklearn.feature_selection import VarianceThreshold
selection= VarianceThreshold(threshold=(.8 * (1- .8)))
X=selection.fit_transform(X)

# %%
X_train, X_test, Y_train, Y_test=train_test_split(X,Y, test_size=0.2)

# %% [markdown]
# #### **Compare ML Models**
# We are going to build 20+ ML models using **lazypredict**

# %%
! pip3 install --user --upgrade pandas
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/51/51/48f3fc47c4e2144da2806dfb6629c4dd1fa3d5a143f9652b141e979a8ca9/pandas-1.2.4-cp37-cp37m-manylinux1_x86_64.whl
# ...
# ERROR: lazypredict 0.2.9 has requirement pandas==1.0.5, but you'll have pandas 1.2.4 which is incompatible.
# ERROR: google-colab 1.0.0 has requirement pandas~=1.1.0; python_version >= "3.0", but you'll have pandas 1.2.4 which is incompatible.
# ...

# %%
clf=LazyRegressor(verbose=0, ignore_warnings=True, custom_metric=None)
train,test=clf.fit(X_train,X_test, Y_train, Y_test)
# Out:
# 100%|██████████| 42/42 [00:09<00:00,  4.26it/s]

# %%
train
# Out:
#                                                               Adjusted R-Squared  ...  Time Taken
# Model                                                                             ...
# Lars                          21642128477750350287837354800878969571523570137...  ...        0.24
# LinearRegression                                     518632128850152640217088.00  ...        0.03
# TransformedTargetRegressor                           518632128850152640217088.00  ...        0.02
# KernelRidge                                                                 2.97  ...        0.05
# GaussianProcessRegressor                                                    2.71  ...        0.03
# PassiveAggressiveRegressor                                                  1.42  ...        0.02
# HuberRegressor                                                              1.37  ...        0.10
# LinearSVR                                                                   1.37  ...        0.06
# ...

# %% [markdown]
# ### **AdaBoostRegressor have the better performence**

# %%
test
# Out:
#                                                               Adjusted R-Squared  ...  Time Taken
# Model                                                                             ...
# Lars                          21642128477750350287837354800878969571523570137...  ...        0.24
# LinearRegression                                     518632128850152640217088.00  ...        0.03
# TransformedTargetRegressor                           518632128850152640217088.00  ...        0.02
# KernelRidge                                                                 2.97  ...        0.05
# GaussianProcessRegressor                                                    2.71  ...        0.03
# PassiveAggressiveRegressor                                                  1.42  ...        0.02
# HuberRegressor                                                              1.37  ...        0.10
# LinearSVR                                                                   1.37  ...        0.06
# ...

# %% [markdown]
# #### **Data Visualization of the model performance**

# %% [markdown]
# #### Bar plot for R-Squared values

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(5,5))
sns.set_theme(style='whitegrid')
ax=sns.barplot(y=train.index, x='R-Squared', data=train)
ax.set(xlim=(0,1))
# Out:
# [(0.0, 1.0)]

# %% [markdown]
# #### Bar plot for RMSE values

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(5,10))
sns.set_theme(style='whitegrid')
ax=sns.barplot(y=train.index, x='RMSE', data=train)
ax.set(xlim=(0,10))
# Out:
# [(0.0, 10.0)]

# %% [markdown]
# #### Bar plot for calculation time

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(5,10))
sns.set_theme(style='whitegrid')
ax=sns.barplot(y=train.index, x='Time Taken', data=train)
ax.set(xlim=(0,10))
# Out:
# [(0.0, 10.0)]

# %% [markdown]
# ## **Dump the model as Pickle Object**

# %%
import pickle

# %%
pickle.dump(model,open('SARS coronavirus_model.pkl', 'wb'))
